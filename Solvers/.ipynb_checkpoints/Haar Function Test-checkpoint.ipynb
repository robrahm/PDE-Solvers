# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from My_Solvers.pde_solvers import fdm

# %%
def create_haar(Y):
    N = int(math.log2(Y.size))
    A = np.zeros((N + 1, 2**N))
    A[0,:] = Y 
    for M in range(1, N + 1):
        L = 2**M
        k = 0
        while k*L < 2**N:
            A[M, k*L: (k+1)*L] = .5 * (A[M - 1, k*L] + A[M-1, (k+1)*L - 1])
            k += 1
    H = A[:-1,] - A[1:,]
    m = 1/2**np.arange(N - 1,-1,-1)
    m = m.reshape(N, 1)
    C = np.sqrt(m) * H
    
    return A, H, C

# %%
def f(x):
    #return np.where(x < 0.25, 1, 2)
    #return np.cos(x)**np.exp(np.cos(40*x**2))
    return x**2
Num = 4
Y = f(np.linspace(0,1,2**(Num)))

A, H, C = create_haar(Y)

# %% [markdown]
# First, plot the haar transform and the given function and compare.

# %%
Z = np.zeros(H.shape[1])
X = np.linspace(0,1,Z.size)
for k in range(H.shape[0]):
    Z += H[k,:]
Z += A[-1,:]
plt.plot(X, Z)
plt.plot(np.linspace(0,1, 2**(16)), f(np.linspace(0,1, 2**(16))))

# %% [markdown]
# Now add noise and use Haars to de--noise. But first plot the noisy signal.

# %%
Yn = Y + np.random.normal(0, .01, size = Y.shape)
An, Hn, Cn = create_haar(Yn)
Zn = np.zeros(Hn.shape[1])
Xn = np.linspace(0,1,Zn.size)
for k in range(Hn.shape[0]):
    Zn += Hn[k,:]
Zn += An[-1,:]
plt.plot(Xn, Zn)
plt.plot(Xn, Yn)

# %% [markdown]
# C is the matrix of coefficients. So find where those are "big" and delete the corresponding values from H.

# %%
th = .1 * np.max(np.abs(Cn))
Hdn = np.where(np.abs(Cn) >= th, Hn, 0)
#Hdn = H * Cdn

Zdn = np.zeros(Hdn.shape[1])
Xn = np.linspace(0,1,Zn.size)
for k in range(Hn.shape[0]):
    Zdn += Hdn[k,:]
Zdn += An[-1,:]
plt.plot(Xn, Zdn)
#plt.plot(Xn, Yn)
#plt.plot(X, Y)

# %%
def haar(x):
    return np.where(x < .5, 1, -1)
T1, X1, U1 = fdm(haar, 1, 2**Num, 1, 1, lbc = [0,1,0], rbc = [0,1,0])
# Out:
# None
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 def haar(x):
#       2     np.where(x < .5, 1, -1)
# ----> 3 T1, X1, U1 = fdm(haar, 1, 2**Num, 1, 1, lbc = [0,1,0], rbc = [0,1,0])
#
# File ~\Documents\PDE-Solvers\Solvers\My_Solvers\pde_solvers.py:200, in fdm(u0, alpha, dx, t_end, L, convec, dt, lbc, rbc, g)
#     198 al = .5 * (a(X[2:]) + a(X[1:-1]))
#     199 ar = .5 * (a(X[0:-2]) + a(X[1:-1]))
# --> 200 Ul = U[-1,2:] - U[-1,1:-1]
#     201 Ur = U[-1,1:-1] - U[-1, 0:-2]
#     202 u = U[-1,1:-1] + dtdx * (al * Ul - ar * Ur) + dt * (c(X[2:]) * U[-1,2:] - c(X[0:-2]) * U[-1, 0:-2]) / (2 * dx)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
